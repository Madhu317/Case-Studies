# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import pylab

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-whitegrid')

import seaborn as sns
sns.set(style="whitegrid")

# %config IPCompleter.greedy=True

# %%
Items = pd.read_csv("C:\\Study\\530-MachineLearningI\\Project\\predict_future_sales\\items.csv")
ItemCat = pd.read_csv("C:\\Study\\530-MachineLearningI\\Project\\predict_future_sales\\item_categories.csv")
SalesTrain = pd.read_csv("C:\\Study\\530-MachineLearningI\\Project\\predict_future_sales\\sales_train_v2.csv")
Shops = pd.read_csv("C:\\Study\\530-MachineLearningI\\Project\\predict_future_sales\\shops.csv")
SalesTest = pd.read_csv("C:\\Study\\530-MachineLearningI\\Project\\predict_future_sales\\test.csv")
SampleSubmission = pd.read_csv("C:\\Study\\530-MachineLearningI\\Project\\predict_future_sales\\sample_submission.csv")

# %%
SalesTrain.head(10)
# Out:
#          date  date_block_num  shop_id  item_id  item_price  item_cnt_day
# 0  02.01.2013               0       59    22154      999.00           1.0
# 1  03.01.2013               0       25     2552      899.00           1.0
# 2  05.01.2013               0       25     2552      899.00          -1.0
# 3  06.01.2013               0       25     2554     1709.05           1.0
# 4  15.01.2013               0       25     2555     1099.00           1.0
# 5  10.01.2013               0       25     2564      349.00           1.0
# 6  02.01.2013               0       25     2565      549.00           1.0
# 7  04.01.2013               0       25     2572      239.00           1.0
# 8  11.01.2013               0       25     2572      299.00           1.0
# 9  03.01.2013               0       25     2573      299.00           3.0

# %%
SalesTrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
# date              object
# date_block_num    int64
# shop_id           int64
# item_id           int64
# item_price        float64
# item_cnt_day      float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %% [markdown]
# ### Check if any of the files contain any missing values

# %%
SalesTrain[SalesTrain.isnull().any(axis=1)].head()     #NO MISSING VALUE
# Out:
# Empty DataFrame
# Columns: [date, date_block_num, shop_id, item_id, item_price, item_cnt_day]
# Index: []

# %%
SalesTest[SalesTest.isnull().any(axis=1)].head()   #NO MISSING VALUE
# Out:
# Empty DataFrame
# Columns: [ID, shop_id, item_id]
# Index: []

# %%
Items[Items.isnull().any(axis=1)].head()   #NO MISSING VALUE
# Out:
# Empty DataFrame
# Columns: [item_name, item_id, item_category_id]
# Index: []

# %%
ItemCat[ItemCat.isnull().any(axis=1)].head()    #NO MISSING VALUE
# Out:
# Empty DataFrame
# Columns: [item_category_name, item_category_id]
# Index: []

# %%
Shops[Shops.isnull().any(axis=1)].head()    #NO MISSING VALUE
# Out:
# Empty DataFrame
# Columns: [shop_name, shop_id]
# Index: []

# %% [markdown]
# ### Check any presence of outliers in the data

# %%
plt.plot(SalesTrain['item_id'], SalesTrain['item_price'], 'o', color='black');

# %%
SalesTrain[SalesTrain.item_price > 40000]
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 885138   17.09.2013               8       12    11365     59200.0
# 1006638  24.10.2013               9       12     7238     42000.0
# 1163158  13.12.2013              11       12     6066    307980.0
# 1488135  20.03.2014              14       25    13199     50999.0
# 2143903  20.11.2014              22       12    14173     40900.0
# 2327159  29.01.2015              24       12     7241     49782.0
# 2885692  23.10.2015              33       42    13403     42990.0
# 2893100  20.10.2015              33       38    13403     41990.0
# 2910155  20.10.2015              33       12    13403     41990.0
# 2910156  29.10.2015              33       12    13403     42990.0
# 2913267  22.10.2015              33       18    13403     41990.0
# 2917760  20.10.2015              33        3    13403     42990.0
# 2927572  22.10.2015              33       28    13403     40991.0
# 2931380  20.10.2015              33       22    13403     42990.0
#
#          item_cnt_day
# 885138            1.0
# 1006638           1.0
# 1163158           1.0
# 1488135           1.0
# 2143903           1.0
# 2327159           1.0
# 2885692           1.0
# 2893100           1.0
# 2910155           1.0
# 2910156           1.0
# 2913267           1.0
# 2917760           1.0
# 2927572           1.0
# 2931380           1.0

# %%
Items[Items.item_id == 6066]
# Out:
#                  item_name  item_id  item_category_id
# 6066  Radmin 3  - 522 лиц.     6066                75

# %%
ItemCat[ItemCat.item_category_id == 75]
# Out:
#               item_category_name  item_category_id
# 75  Программы - Для дома и офиса                75

# %%
SalesTrain[SalesTrain.item_id == 6066]
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 1163158  13.12.2013              11       12     6066    307980.0
#
#          item_cnt_day
# 1163158           1.0

# %%
Shops[Shops.shop_id == 12]
# Out:
#               shop_name  shop_id
# 12  Интернет-магазин ЧС       12

# %% [markdown]
# #### The record which appeared to be an outlier seems to be a genuine sale

# %%
SampleSubmission.head(10)
# Out:
#    ID  item_cnt_month
# 0   0             0.5
# 1   1             0.5
# 2   2             0.5
# 3   3             0.5
# 4   4             0.5
# 5   5             0.5
# 6   6             0.5
# 7   7             0.5
# 8   8             0.5
# 9   9             0.5

# %%
SalesTrain.sort_values(by = 'item_price', ascending = False, inplace = False).head()
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 1163158  13.12.2013              11       12     6066    307980.0
# 885138   17.09.2013               8       12    11365     59200.0
# 1488135  20.03.2014              14       25    13199     50999.0
# 2327159  29.01.2015              24       12     7241     49782.0
# 2931380  20.10.2015              33       22    13403     42990.0
#
#          item_cnt_day
# 1163158           1.0
# 885138            1.0
# 1488135           1.0
# 2327159           1.0
# 2931380           1.0

# %% [markdown]
# ### Convert the date object to datetime column in DF SalesTrain

# %%
SalesTrain['date'] =  pd.to_datetime(SalesTrain['date'],format= '%d.%m.%Y')

# %%
SalesTrain.dtypes
# Out:
# date              datetime64[ns]
# date_block_num             int64
# shop_id                    int64
# item_id                    int64
# item_price               float64
# item_cnt_day             float64
# dtype: object

# %% [markdown]
# ### Change the data in an aggregate format group by month

# %%
 SalesTrain['month'] = pd.DatetimeIndex(SalesTrain['date']).month
 SalesTrain['year'] = pd.DatetimeIndex(SalesTrain['date']).year

# %%
SalesTrain.head(10)
# Out:
#         date  date_block_num  shop_id  item_id  item_price  item_cnt_day  \
# 0 2013-01-02               0       59    22154      999.00           1.0
# 1 2013-01-03               0       25     2552      899.00           1.0
# 2 2013-01-05               0       25     2552      899.00          -1.0
# 3 2013-01-06               0       25     2554     1709.05           1.0
# 4 2013-01-15               0       25     2555     1099.00           1.0
# 5 2013-01-10               0       25     2564      349.00           1.0
# 6 2013-01-02               0       25     2565      549.00           1.0
# 7 2013-01-04               0       25     2572      239.00           1.0
# 8 2013-01-11               0       25     2572      299.00           1.0
# 9 2013-01-03               0       25     2573      299.00           3.0
#
#    month  year
# 0      1  2013
# 1      1  2013
# 2      1  2013
# 3      1  2013
# 4      1  2013
# 5      1  2013
# 6      1  2013
# 7      1  2013
# 8      1  2013
# 9      1  2013

# %%
SalesTrainSub = SalesTrain.iloc[:,1:8]

# %%
SalesTrainSub.head(3)
# Out:
#    date_block_num  shop_id  item_id  item_price  item_cnt_day  month  year
# 0               0       59    22154       999.0           1.0      1  2013
# 1               0       25     2552       899.0           1.0      1  2013
# 2               0       25     2552       899.0          -1.0      1  2013

# %% [markdown]
# ### Data Exploration to understand the trends

# %% [markdown]
# #### The variations in item price in 3 years

# %%
with sns.axes_style("whitegrid", {'axes.grid' : True}):
    fig, ax = plt.subplots(1,1, figsize=(15,6))
month_itemprice = sns.barplot(x="year", y="item_price", hue="month", data=SalesTrainSub)

# %%
sns.pairplot(SalesTrainSub, x_vars="year", y_vars="item_cnt_day", size=8, aspect=0.5, kind='reg')
# Out:
# C:\Users\rgoyal\Anaconda3\Lib\site-packages\seaborn\axisgrid.py:2065: UserWarning: The `size` parameter has been renamed to `height`; pleaes update your code.
#   warnings.warn(msg, UserWarning)

# %%
# The correlation plot for the attributes 

corr_plot = sns.pairplot(SalesTrainSub)

# %%
month_itemprice_2 = sns.FacetGrid(SalesTrainSub, col = "year")
month_itemprice_2 = month_itemprice_2.map(plt.scatter, "month", "item_price", edgecolor="w")

# %%
month_itemprice_2 = sns.FacetGrid(SalesTrainSub, col = "year")
month_itemprice_2 = month_itemprice_2.map(plt.scatter, "month", "item_cnt_day", edgecolor="w")

# %%
with sns.axes_style("whitegrid", {'axes.grid' : True}):
    fig, ax = plt.subplots(1,1, figsize=(15,6))
sns.violinplot(x = "shop_id", data=SalesTrainSub, palette="Set3")
plt.show()

# %%
# from SalesTrainSub dataset, get the top 20 shops sold most number of items
Top_20_Shops = SalesTrainSub.groupby(['shop_id'])['item_cnt_day'].agg({'item_cnt_day': 'sum'}).sort_values(by='item_cnt_day', ascending=False)[:20]
Top_20_Shops['shop_id'] = Top_20_Shops.index

Top_20_Shops.sort_values(by='item_cnt_day', ascending=False)
Top_20_Shops.reset_index(drop=True, inplace=True)
Top_20_Shops
# Out:
# C:\Users\rgoyal\Anaconda3\Lib\site-packages\ipykernel_launcher.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#     item_cnt_day  shop_id
# 0       310777.0       31
# 1       241920.0       25
# 2       185790.0       54
# 3       184557.0       28
# 4       144934.0       42
# 5       141107.0       57
# 6       136657.0       27
# 7       100489.0        6
# 8        81734.0       58
# 9        78990.0       46
# 10       78079.0       56
# 11       76238.0       50
# 12       73478.0       12
# 13       73455.0       19
# 14       71201.0       15
# 15       69016.0       35
# 16       68560.0       21
# 17       67890.0       26
# 18       67637.0       47
# 19       67058.0        7

# %%
# See the top 20 shops among the 60 who are top sellers

with sns.axes_style("whitegrid", {'axes.grid' : True}):
    fig, ax = plt.subplots(1,1, figsize=(15,6))

sns.set(font_scale=1)
ax.spines["top"].set_visible(False)    
ax.spines["bottom"].set_visible(False)    
ax.spines["right"].set_visible(False)    
ax.spines["left"].set_visible(False) 

sns.barplot(x = 'shop_id', y = 'item_cnt_day', data=Top_20_Shops, palette="Paired")
ax.legend(bbox_to_anchor=(1, 0.5))
# from SalesTrainSub dataset, get the top 20 shops sold most number of items
Top_20_Shops = SalesTrainSub.groupby(['shop_id'])['item_cnt_day'].agg({'item_cnt_day': 'sum'}).sort_values(by='item_cnt_day', ascending=False)[:20]
Top_20_Shops['shop_id'] = Top_20_Shops.index

Top_20_Shops.sort_values(by='item_cnt_day', ascending=False)#plt.xticks(rotation=-45)
# Out:
# No handles with labels found to put in legend.

# %%
#Top_20_Shops['shop_id'] = Top_20_Shops.index


Top_items = SalesTrainSub.groupby(['year','item_id'])['item_cnt_day'].agg({'item_cnt_day': 'sum'}).sort_values(by='item_cnt_day', ascending=False)
Top_items['year'] = Top_items.index.get_level_values('year') 
Top_items['item_id'] = Top_items.index.get_level_values('item_id') 
Top_items
# Out:
# C:\Users\rgoyal\Anaconda3\Lib\site-packages\ipykernel_launcher.py:4: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   after removing the cwd from sys.path.
#               item_cnt_day  year  item_id
# year item_id
# 2014 20949         85288.0  2014    20949
# 2013 20949         63748.0  2013    20949
# 2015 20949         38606.0  2015    20949
# 2013 2808          12214.0  2013     2808
#      3732          11981.0  2013     3732
# 2015 3731          10099.0  2015     3731
# 2013 3734           7649.0  2013     3734
# 2014 17717          7392.0  2014    17717
# 2015 17717          7268.0  2015    17717
# 2014 2814           7096.0  2014     2814
#      5822           6542.0  2014     5822
# 2013 16787          6430.0  2013    16787
#      6738           5924.0  2013     6738
#      1830           5640.0  2013     1830
# 2014 6675           5533.0  2014     6675
# 2013 2445           5330.0  2013     2445
# 2014 3733           5322.0  2014     3733
#      16790          5292.0  2014    16790
#      1855           5192.0  2014     1855
#      3928           5116.0  2014     3928
# 2013 3331           5114.0  2013     3331
#      15044          4988.0  2013    15044
# 2015 10210          4876.0  2015    10210
# 2014 9242           4561.0  2014     9242
# 2013 1849           4552.0  2013     1849
# 2014 7018           4469.0  2014     7018
#      4181           4434.0  2014     4181
# 2015 11373          4408.0  2015    11373
# 2013 6740           4241.0  2013     6740
# 2015 10209          4213.0  2015    10209
# ...                    ...   ...      ...
# 2014 7285              0.0  2014     7285
# 2013 4591              0.0  2013     4591
# 2015 12126             0.0  2015    12126
# 2014 10228             0.0  2014    10228
#      3718              0.0  2014     3718
# 2013 6923              0.0  2013     6923
#      12256             0.0  2013    12256
#      8515              0.0  2013     8515
#      2199              0.0  2013     2199
#      13477             0.0  2013    13477
# 2014 9345              0.0  2014     9345
#      19493             0.0  2014    19493
#      6666              0.0  2014     6666
# 2015 15904             0.0  2015    15904
#      19303             0.0  2015    19303
#      13427             0.0  2015    13427
# 2013 5518              0.0  2013     5518
# 2014 6850              0.0  2014     6850
#      7547              0.0  2014     7547
# 2015 7048             -1.0  2015     7048
# 2013 18062            -1.0  2013    18062
# 2015 9242             -1.0  2015     9242
# 2013 11871            -1.0  2013    11871
#      13474            -1.0  2013    13474
# 2014 3738             -1.0  2014     3738
# 2015 13466            -1.0  2015    13466
#      15018            -1.0  2015    15018
# 2014 5819             -2.0  2014     5819
#      11367            -5.0  2014    11367
# 2013 1590            -11.0  2013     1590
#
# [40328 rows x 3 columns]

# %% [markdown]
# ### Creating a subset of date_block_num, month, item_id and item_cnt_agg to perform regression

# %%
SalesAgg = SalesTrainSub.groupby(['date_block_num', 'month',
                                  'item_id'])['item_cnt_day'].agg({'item_cnt_agg':
                                                                   'sum'}).sort_values(['date_block_num','month','item_id'], ascending=[True, True, True])

SalesAgg['date_block_num'] = SalesAgg.index.get_level_values('date_block_num') 
SalesAgg['month'] = SalesAgg.index.get_level_values('month') 
SalesAgg['item_id'] = SalesAgg.index.get_level_values('item_id') 

SalesAgg.reset_index(drop=True, inplace=True)
SalesAgg = SalesAgg.reindex_axis(['date_block_num','month','item_id','item_cnt_agg'], axis=1)

SalesAgg
# Out:
# C:\Users\rgoyal\Anaconda3\Lib\site-packages\ipykernel_launcher.py:4: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   after removing the cwd from sys.path.
# C:\Users\rgoyal\Anaconda3\Lib\site-packages\ipykernel_launcher.py:11: FutureWarning: '.reindex_axis' is deprecated and will be removed in a future version. Use '.reindex' instead.
#   # This is added back by InteractiveShellApp.init_path()
#         date_block_num  month  item_id  item_cnt_agg
# 0                    0      1       19           1.0
# 1                    0      1       27           7.0
# 2                    0      1       28           8.0
# 3                    0      1       29           4.0
# 4                    0      1       32         299.0
# 5                    0      1       33          61.0
# 6                    0      1       34           9.0
# 7                    0      1       35          78.0
# 8                    0      1       40           4.0
# 9                    0      1       41           9.0
# 10                   0      1       42           2.0
# 11                   0      1       43           2.0
# 12                   0      1       44           6.0
# 13                   0      1       45           8.0
# 14                   0      1       46           2.0
# 15                   0      1       47           6.0
# 16                   0      1       48           7.0
# 17                   0      1       49           5.0
# 18                   0      1       50           2.0
# 19                   0      1       51          13.0
# 20                   0      1       52           7.0
# 21                   0      1       53           8.0
# 22                   0      1       54           6.0
# 23                   0      1       55           4.0
# 24                   0      1       56           1.0
# 25                   0      1       57           1.0
# 26                   0      1       59          18.0
# 27                   0      1       60           6.0
# 28                   0      1       61           2.0
# 29                   0      1       63           4.0
# ...                ...    ...      ...           ...
# 233882              33     10    22020           1.0
# 233883              33     10    22050           3.0
# 233884              33     10    22051           6.0
# 233885              33     10    22058           3.0
# 233886              33     10    22059           2.0
# 233887              33     10    22060           5.0
# 233888              33     10    22071           5.0
# 233889              33     10    22072           1.0
# 233890              33     10    22076           4.0
# 233891              33     10    22087          87.0
# 233892              33     10    22088         185.0
# 233893              33     10    22091          30.0
# 233894              33     10    22092          46.0
# 233895              33     10    22100         158.0
# 233896              33     10    22101          54.0
# 233897              33     10    22102         227.0
# 233898              33     10    22104          14.0
# 233899              33     10    22105          11.0
# 233900              33     10    22106           6.0
# 233901              33     10    22111           1.0
# 233902              33     10    22118           2.0
# 233903              33     10    22139           9.0
# 233904              33     10    22145          13.0
# 233905              33     10    22154           5.0
# 233906              33     10    22158           1.0
# 233907              33     10    22162          10.0
# 233908              33     10    22163          26.0
# 233909              33     10    22164          15.0
# 233910              33     10    22166          11.0
# 233911              33     10    22167          37.0
#
# [233912 rows x 4 columns]

# %% [markdown]
# ### Checking the assumptions of linear regression
#
# #### 1. Linearity
# #### 2. Normality
# #### 3. Homoscedasticity
# #### 4. Multi-collinearity

# %%
# from SalesTrainSub dataset, get the top 20 shops sold most number of items
Top_items_only = SalesTrain.groupby(['item_id'])['item_cnt_day'].agg({'item_cnt_day': 'sum'}).sort_values(by='item_cnt_day', ascending=False)
Top_items_only['item_id'] = Top_items_only.index
Top_items_only.reset_index(drop=True, inplace=True)
Top_items_only
# Out:
# C:\Users\rgoyal\Anaconda3\Lib\site-packages\ipykernel_launcher.py:2: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#        item_cnt_day  item_id
# 0          187642.0    20949
# 1           17245.0     2808
# 2           16642.0     3732
# 3           15830.0    17717
# 4           14515.0     5822
# 5           11688.0     3734
# 6           10289.0     6675
# 7           10099.0     3731
# 8           10032.0     1855
# 9            9227.0    16787
# 10           9012.0     7856
# 11           8869.0     4181
# 12           8262.0     3331
# 13           7788.0     2445
# 14           7588.0     2308
# 15           7551.0     4870
# 16           7351.0     6738
# 17           7105.0     2814
# 18           6975.0     1830
# 19           6563.0    11373
# 20           6548.0     6503
# 21           6523.0     5823
# 22           6506.0     3733
# 23           6270.0     6740
# 24           6244.0     5821
# 25           6219.0    16790
# 26           6163.0    11370
# 27           6141.0     6497
# 28           6002.0     5272
# 29           5991.0     3183
# ...             ...      ...
# 21777           1.0    10564
# 21778           1.0    10565
# 21779           1.0    10570
# 21780           1.0    10577
# 21781           1.0    10607
# 21782           1.0    10639
# 21783           1.0    10640
# 21784           1.0    10648
# 21785           1.0    10850
# 21786           1.0    10681
# 21787           1.0    10655
# 21788           1.0    22169
# 21789           1.0    10752
# 21790           1.0    10835
# 21791           1.0    10695
# 21792           1.0    10799
# 21793           1.0    10696
# 21794           1.0    10698
# 21795           1.0    10705
# 21796           1.0    10753
# 21797           1.0    10685
# 21798           1.0    10745
# 21799           0.0     8515
# 21800           0.0     4591
# 21801           0.0    13477
# 21802           0.0     7547
# 21803          -1.0    13474
# 21804          -1.0    18062
# 21805          -1.0    11871
# 21806         -11.0     1590
#
# [21807 rows x 2 columns]

# %%
sns.scatterplot(data=Top_items_only);

# %%
Top_items_only[Top_items_only['item_cnt_day'] > 175000]
# Out:
#    item_cnt_day  item_id
# 0      187642.0    20949

# %%
Top_items_only.drop([0])
# Out:
#        item_cnt_day  item_id
# 1           17245.0     2808
# 2           16642.0     3732
# 3           15830.0    17717
# 4           14515.0     5822
# 5           11688.0     3734
# 6           10289.0     6675
# 7           10099.0     3731
# 8           10032.0     1855
# 9            9227.0    16787
# 10           9012.0     7856
# 11           8869.0     4181
# 12           8262.0     3331
# 13           7788.0     2445
# 14           7588.0     2308
# 15           7551.0     4870
# 16           7351.0     6738
# 17           7105.0     2814
# 18           6975.0     1830
# 19           6563.0    11373
# 20           6548.0     6503
# 21           6523.0     5823
# 22           6506.0     3733
# 23           6270.0     6740
# 24           6244.0     5821
# 25           6219.0    16790
# 26           6163.0    11370
# 27           6141.0     6497
# 28           6002.0     5272
# 29           5991.0     3183
# 30           5989.0     7894
# ...             ...      ...
# 21777           1.0    10564
# 21778           1.0    10565
# 21779           1.0    10570
# 21780           1.0    10577
# 21781           1.0    10607
# 21782           1.0    10639
# 21783           1.0    10640
# 21784           1.0    10648
# 21785           1.0    10850
# 21786           1.0    10681
# 21787           1.0    10655
# 21788           1.0    22169
# 21789           1.0    10752
# 21790           1.0    10835
# 21791           1.0    10695
# 21792           1.0    10799
# 21793           1.0    10696
# 21794           1.0    10698
# 21795           1.0    10705
# 21796           1.0    10753
# 21797           1.0    10685
# 21798           1.0    10745
# 21799           0.0     8515
# 21800           0.0     4591
# 21801           0.0    13477
# 21802           0.0     7547
# 21803          -1.0    13474
# 21804          -1.0    18062
# 21805          -1.0    11871
# 21806         -11.0     1590
#
# [21806 rows x 2 columns]

# %%
sns.scatterplot(data=Top_items_only);

# %% [markdown]
# ## Decision Tree Classification

# %%
monthly_sales=SalesTrainSub.groupby(["date_block_num","shop_id","item_id"])["item_cnt_day"].agg({"item_cnt_day":"sum"})

monthly_sales['date_block_num'] = monthly_sales.index.get_level_values('date_block_num') 
monthly_sales['shop_id'] = monthly_sales.index.get_level_values('shop_id') 
monthly_sales['item_id'] = monthly_sales.index.get_level_values('item_id') 
monthly_sales.reset_index(drop=True, inplace=True)

monthly_sales = monthly_sales.reindex_axis(['date_block_num','shop_id','item_id','item_cnt_day'], axis=1)
monthly_sales
# Out:
# C:\Users\rgoyal\Anaconda3\Lib\site-packages\ipykernel_launcher.py:1: FutureWarning: using a dict on a Series for aggregation
# is deprecated and will be removed in a future version
#   """Entry point for launching an IPython kernel.
# C:\Users\rgoyal\Anaconda3\Lib\site-packages\ipykernel_launcher.py:8: FutureWarning: '.reindex_axis' is deprecated and will be removed in a future version. Use '.reindex' instead.
#          date_block_num  shop_id  item_id  item_cnt_day
# 0                     0        0       32           6.0
# 1                     0        0       33           3.0
# 2                     0        0       35           1.0
# 3                     0        0       43           1.0
# 4                     0        0       51           2.0
# 5                     0        0       61           1.0
# 6                     0        0       75           1.0
# 7                     0        0       88           1.0
# 8                     0        0       95           1.0
# 9                     0        0       96           1.0
# 10                    0        0       98          25.0
# 11                    0        0      111           1.0
# 12                    0        0      149           3.0
# 13                    0        0      151           1.0
# 14                    0        0      153           1.0
# 15                    0        0      198           1.0
# 16                    0        0      210           2.0
# 17                    0        0      282           1.0
# 18                    0        0      306           1.0
# 19                    0        0      351           1.0
# 20                    0        0      421           1.0
# 21                    0        0      438           1.0
# 22                    0        0      482           2.0
# 23                    0        0      484           4.0
# 24                    0        0      491           1.0
# 25                    0        0      498           1.0
# 26                    0        0      556           9.0
# 27                    0        0      642           6.0
# 28                    0        0      651           7.0
# 29                    0        0      657           2.0
# ...                 ...      ...      ...           ...
# 1609094              33       59    19894           1.0
# 1609095              33       59    19985           1.0
# 1609096              33       59    20303           1.0
# 1609097              33       59    20305           1.0
# 1609098              33       59    20335           1.0
# 1609099              33       59    20355           1.0
# 1609100              33       59    20392           1.0
# 1609101              33       59    20604           2.0
# 1609102              33       59    20614           1.0
# 1609103              33       59    20629           1.0
# 1609104              33       59    20730           1.0
# 1609105              33       59    20751           1.0
# 1609106              33       59    20866           4.0
# 1609107              33       59    20949          19.0
# 1609108              33       59    21361           1.0
# 1609109              33       59    21364           1.0
# 1609110              33       59    21369           2.0
# 1609111              33       59    21377           1.0
# 1609112              33       59    21386           1.0
# 1609113              33       59    21404           1.0
# 1609114              33       59    21427           1.0
# 1609115              33       59    21449           2.0
# 1609116              33       59    21672           1.0
# 1609117              33       59    21811           1.0
# 1609118              33       59    21812           1.0
# 1609119              33       59    22087           6.0
# 1609120              33       59    22088           2.0
# 1609121              33       59    22091           1.0
# 1609122              33       59    22100           1.0
# 1609123              33       59    22102           1.0
#
# [1609124 rows x 4 columns]

# %%
from sklearn import tree

# %%
model = tree.DecisionTreeClassifier(criterion='gini') 

cols = ['shop_id','date_block_num','item_id']
X = monthly_sales[cols] # Predictor columns
y = monthly_sales.item_cnt_day  # Target variable

# %%
model.fit(X, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
model.score(X, y)
# Out:
# 1.0

# %%
X_test = SalesTest[['shop_id','item_id']]
X_test.insert(loc=1, column='date_block_num', value='34')  
X_test
# Out:
#         shop_id date_block_num  item_id
# 0             5             34     5037
# 1             5             34     5320
# 2             5             34     5233
# 3             5             34     5232
# 4             5             34     5268
# 5             5             34     5039
# 6             5             34     5041
# 7             5             34     5046
# 8             5             34     5319
# 9             5             34     5003
# 10            5             34     4806
# 11            5             34     4843
# 12            5             34     4607
# 13            5             34     4869
# 14            5             34     4870
# 15            5             34     4872
# 16            5             34     4874
# 17            5             34     4678
# 18            5             34     4892
# 19            5             34     4964
# 20            5             34     4717
# 21            5             34     5002
# 22            5             34     5823
# 23            5             34     5814
# 24            5             34     5900
# 25            5             34     5907
# 26            5             34     5908
# 27            5             34     5643
# 28            5             34     5657
# 29            5             34     5675
# ...         ...            ...      ...
# 214170       45             34    14543
# 214171       45             34    19253
# 214172       45             34    17957
# 214173       45             34    12470
# 214174       45             34     7543
# 214175       45             34     6661
# 214176       45             34    11137
# 214177       45             34    11489
# 214178       45             34     9782
# 214179       45             34     2972
# 214180       45             34    19889
# 214181       45             34    20650
# 214182       45             34     5665
# 214183       45             34     9978
# 214184       45             34    10767
# 214185       45             34    14443
# 214186       45             34    14341
# 214187       45             34     5401
# 214188       45             34     9500
# 214189       45             34    16007
# 214190       45             34     3280
# 214191       45             34     4393
# 214192       45             34     4352
# 214193       45             34    18049
# 214194       45             34    18027
# 214195       45             34    18454
# 214196       45             34    16188
# 214197       45             34    15757
# 214198       45             34    19648
# 214199       45             34      969
#
# [214200 rows x 3 columns]

# %%
#Predict Output
predicted= model.predict(X_test)

# %%
predicted_df = pd.DataFrame(predicted)
predicted_df = predicted_df.join(X_test)
predicted_df
# Out:
#           0  shop_id date_block_num  item_id
# 0       1.0        5             34     5037
# 1       3.0        5             34     5320
# 2       1.0        5             34     5233
# 3       1.0        5             34     5232
# 4       1.0        5             34     5268
# 5       1.0        5             34     5039
# 6       2.0        5             34     5041
# 7       1.0        5             34     5046
# 8       3.0        5             34     5319
# 9       1.0        5             34     5003
# 10      3.0        5             34     4806
# 11      2.0        5             34     4843
# 12      1.0        5             34     4607
# 13      1.0        5             34     4869
# 14      2.0        5             34     4870
# 15      6.0        5             34     4872
# 16      3.0        5             34     4874
# 17      1.0        5             34     4678
# 18      2.0        5             34     4892
# 19      1.0        5             34     4964
# 20      1.0        5             34     4717
# 21      1.0        5             34     5002
# 22      1.0        5             34     5823
# 23      1.0        5             34     5814
# 24      3.0        5             34     5900
# 25      1.0        5             34     5907
# 26      1.0        5             34     5908
# 27      1.0        5             34     5643
# 28      2.0        5             34     5657
# 29      7.0        5             34     5675
# ...     ...      ...            ...      ...
# 214170  1.0       45             34    14543
# 214171  1.0       45             34    19253
# 214172  1.0       45             34    17957
# 214173  1.0       45             34    12470
# 214174  1.0       45             34     7543
# 214175  1.0       45             34     6661
# 214176  1.0       45             34    11137
# 214177  1.0       45             34    11489
# 214178  1.0       45             34     9782
# 214179  1.0       45             34     2972
# 214180  1.0       45             34    19889
# 214181  1.0       45             34    20650
# 214182  1.0       45             34     5665
# 214183  2.0       45             34     9978
# 214184  1.0       45             34    10767
# 214185  1.0       45             34    14443
# 214186  1.0       45             34    14341
# 214187  1.0       45             34     5401
# 214188  1.0       45             34     9500
# 214189  1.0       45             34    16007
# 214190  1.0       45             34     3280
# 214191  1.0       45             34     4393
# 214192  1.0       45             34     4352
# 214193  1.0       45             34    18049
# 214194  1.0       45             34    18027
# 214195  1.0       45             34    18454
# 214196  1.0       45             34    16188
# 214197  1.0       45             34    15757
# 214198  1.0       45             34    19648
# 214199  1.0       45             34      969
#
# [214200 rows x 4 columns]

# %%
predicted_df.columns  = ['item_cnt', 'shop_id', 'date_block_num','item_id']
predicted_df = predicted_df.reindex_axis(['shop_id','date_block_num','item_id','item_cnt'], axis=1)
# Out:
# C:\Users\rgoyal\Anaconda3\Lib\site-packages\ipykernel_launcher.py:2: FutureWarning: '.reindex_axis' is deprecated and will be removed in a future version. Use '.reindex' instead.

# %%
predicted_df
# Out:
#         shop_id date_block_num  item_id  item_cnt
# 0             5             34     5037       1.0
# 1             5             34     5320       3.0
# 2             5             34     5233       1.0
# 3             5             34     5232       1.0
# 4             5             34     5268       1.0
# 5             5             34     5039       1.0
# 6             5             34     5041       2.0
# 7             5             34     5046       1.0
# 8             5             34     5319       3.0
# 9             5             34     5003       1.0
# 10            5             34     4806       3.0
# 11            5             34     4843       2.0
# 12            5             34     4607       1.0
# 13            5             34     4869       1.0
# 14            5             34     4870       2.0
# 15            5             34     4872       6.0
# 16            5             34     4874       3.0
# 17            5             34     4678       1.0
# 18            5             34     4892       2.0
# 19            5             34     4964       1.0
# 20            5             34     4717       1.0
# 21            5             34     5002       1.0
# 22            5             34     5823       1.0
# 23            5             34     5814       1.0
# 24            5             34     5900       3.0
# 25            5             34     5907       1.0
# 26            5             34     5908       1.0
# 27            5             34     5643       1.0
# 28            5             34     5657       2.0
# 29            5             34     5675       7.0
# ...         ...            ...      ...       ...
# 214170       45             34    14543       1.0
# 214171       45             34    19253       1.0
# 214172       45             34    17957       1.0
# 214173       45             34    12470       1.0
# 214174       45             34     7543       1.0
# 214175       45             34     6661       1.0
# 214176       45             34    11137       1.0
# 214177       45             34    11489       1.0
# 214178       45             34     9782       1.0
# 214179       45             34     2972       1.0
# 214180       45             34    19889       1.0
# 214181       45             34    20650       1.0
# 214182       45             34     5665       1.0
# 214183       45             34     9978       2.0
# 214184       45             34    10767       1.0
# 214185       45             34    14443       1.0
# 214186       45             34    14341       1.0
# 214187       45             34     5401       1.0
# 214188       45             34     9500       1.0
# 214189       45             34    16007       1.0
# 214190       45             34     3280       1.0
# 214191       45             34     4393       1.0
# 214192       45             34     4352       1.0
# 214193       45             34    18049       1.0
# 214194       45             34    18027       1.0
# 214195       45             34    18454       1.0
# 214196       45             34    16188       1.0
# 214197       45             34    15757       1.0
# 214198       45             34    19648       1.0
# 214199       45             34      969       1.0
#
# [214200 rows x 4 columns]

# %% [markdown]
# #### Exporting the dataframe to SalesTest_DecisionTreeClass.csv

# %%
predicted_df.to_csv("C:\\Study\\530-MachineLearningI\\Project\\predict_future_sales\\SalesTest_DecisionTreeClass.csv", sep=',')

# %%
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(model, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True)

# %%
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# ## Decision Tree Regressor

# %%
cols_regr = ['shop_id','date_block_num','item_id']
X2 = monthly_sales[cols_regr] # Predictor columns
Y2 = monthly_sales.item_cnt_day  # Target variable

# Fitting Simple Linear Regression model to the data set
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state = 0)
regressor.fit(X2, Y2)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')

# %%
y_pred = regressor.predict([['5','34','5675']])
y_pred
# Out:
# array([7.])

# %%
SalesTest_regr = SalesTest[['shop_id','item_id']]
SalesTest_regr.insert(loc=1, column='date_block_num', value='34')

SalesTest_regr
# Out:
#         shop_id date_block_num  item_id
# 0             5             34     5037
# 1             5             34     5320
# 2             5             34     5233
# 3             5             34     5232
# 4             5             34     5268
# 5             5             34     5039
# 6             5             34     5041
# 7             5             34     5046
# 8             5             34     5319
# 9             5             34     5003
# 10            5             34     4806
# 11            5             34     4843
# 12            5             34     4607
# 13            5             34     4869
# 14            5             34     4870
# 15            5             34     4872
# 16            5             34     4874
# 17            5             34     4678
# 18            5             34     4892
# 19            5             34     4964
# 20            5             34     4717
# 21            5             34     5002
# 22            5             34     5823
# 23            5             34     5814
# 24            5             34     5900
# 25            5             34     5907
# 26            5             34     5908
# 27            5             34     5643
# 28            5             34     5657
# 29            5             34     5675
# ...         ...            ...      ...
# 214170       45             34    14543
# 214171       45             34    19253
# 214172       45             34    17957
# 214173       45             34    12470
# 214174       45             34     7543
# 214175       45             34     6661
# 214176       45             34    11137
# 214177       45             34    11489
# 214178       45             34     9782
# 214179       45             34     2972
# 214180       45             34    19889
# 214181       45             34    20650
# 214182       45             34     5665
# 214183       45             34     9978
# 214184       45             34    10767
# 214185       45             34    14443
# 214186       45             34    14341
# 214187       45             34     5401
# 214188       45             34     9500
# 214189       45             34    16007
# 214190       45             34     3280
# 214191       45             34     4393
# 214192       45             34     4352
# 214193       45             34    18049
# 214194       45             34    18027
# 214195       45             34    18454
# 214196       45             34    16188
# 214197       45             34    15757
# 214198       45             34    19648
# 214199       45             34      969
#
# [214200 rows x 3 columns]

# %%
predicted_df_regr = pd.DataFrame(regressor.predict(SalesTest_regr))
predicted_df_regr = SalesTest_regr.join(predicted_df_regr)

predicted_df_regr = predicted_df_regr.reindex_axis(['shop_id','date_block_num','item_id','item_cnt'], axis=1)
predicted_df_regr
# Out:
#         shop_id date_block_num  item_id    0
# 0             5             34     5037  1.0
# 1             5             34     5320  1.0
# 2             5             34     5233  1.0
# 3             5             34     5232  1.0
# 4             5             34     5268  1.0
# 5             5             34     5039  1.0
# 6             5             34     5041  2.0
# 7             5             34     5046  1.0
# 8             5             34     5319  1.0
# 9             5             34     5003  1.0
# 10            5             34     4806  3.0
# 11            5             34     4843  1.0
# 12            5             34     4607  2.0
# 13            5             34     4869  1.0
# 14            5             34     4870  2.0
# 15            5             34     4872  6.0
# 16            5             34     4874  3.0
# 17            5             34     4678  1.0
# 18            5             34     4892  2.0
# 19            5             34     4964  2.0
# 20            5             34     4717  1.0
# 21            5             34     5002  1.0
# 22            5             34     5823  1.0
# 23            5             34     5814  1.0
# 24            5             34     5900  3.0
# 25            5             34     5907  1.0
# 26            5             34     5908  1.0
# 27            5             34     5643  1.0
# 28            5             34     5657  2.0
# 29            5             34     5675  7.0
# ...         ...            ...      ...  ...
# 214170       45             34    14543  1.0
# 214171       45             34    19253  2.0
# 214172       45             34    17957  1.0
# 214173       45             34    12470  1.0
# 214174       45             34     7543  1.0
# 214175       45             34     6661  1.0
# 214176       45             34    11137  1.0
# 214177       45             34    11489  1.0
# 214178       45             34     9782  1.0
# 214179       45             34     2972  1.0
# 214180       45             34    19889  1.0
# 214181       45             34    20650  1.0
# 214182       45             34     5665  1.0
# 214183       45             34     9978  1.0
# 214184       45             34    10767  1.0
# 214185       45             34    14443  2.0
# 214186       45             34    14341  1.0
# 214187       45             34     5401  1.0
# 214188       45             34     9500  1.0
# 214189       45             34    16007  1.0
# 214190       45             34     3280  1.0
# 214191       45             34     4393  1.0
# 214192       45             34     4352  1.0
# 214193       45             34    18049  1.0
# 214194       45             34    18027  1.0
# 214195       45             34    18454  1.0
# 214196       45             34    16188  1.0
# 214197       45             34    15757  1.0
# 214198       45             34    19648  1.0
# 214199       45             34      969  1.0
#
# [214200 rows x 4 columns]

# %% [markdown]
# #### Exporting the dataframe to SalesTest_DecisionTreeRegr.csv

# %%
predicted_df_regr.to_csv("C:\\Study\\530-MachineLearningI\\Project\\predict_future_sales\\SalesTest_DecisionTreeRegr.csv", sep=',')

# %%
#visualizing decision tree
from sklearn.externals.six import StringIO
from IPython.display import Image
from sklearn.tree import export_graphviz
import pydotplus

dot_data = StringIO()

export_graphviz(regressor, out_file=dot_data, max_depth=5,
filled=True, rounded=True,
special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())
